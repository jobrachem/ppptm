# %%
from ppptm.io import load_americas
from ppptm.util.summary import plot_df
from ppptm.util.locs import LocationVars
from ppptm.model2 import Model

# %%
data = load_americas()

# %%
locs = LocationVars.new_from(data.locs)

# %%
model = Model.new_G(y=data.obs, locs=locs, locscale=True)
# Out:
# liesel.model.nodes - WARNING - Calc(name="") was not updated during initialization, because the following exception occured: RuntimeError('Error while updating Calc(name="").'). See debug log for the full traceback.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/git/ppptm/.venv/lib/python3.13/site-packages/liesel/model/nodes.py:790, in Calc.update(self)
#     789 try:
# --> 790     self._value = self.function(*args, **kwargs)
#     791 except Exception as e:
#
# File ~/Documents/git/ppptm/src/ppptm/nodes/kernel.py:37, in GPKernel.__init__.<locals>._evaluate_kernel(x1, x2, amplitude, length_scale)
#      29 kernel_ = tfk.FeatureScaled(
#      30     kernel(
#      31         amplitude=jnp.array(1.0),
#    (...)     34     scale_diag=length_scale,
#      35 )
# ---> 37 return jnp.outer(amplitude, amplitude) * kernel_.matrix(x1, x2)
#
# ...
